# %%
import pandas as pd

# %%
#read the csv File
df_k = pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\kerala_routes.csv')

df_k
# Out:
#                          Route_name  \
# 0            Bangalore to Kozhikode
# 1            Kozhikode to Ernakulam
# 2            Kozhikode to Bangalore
# 3            Ernakulam to Kozhikode
# 4               Kozhikode to Mysore
# 5               Mysore to Kozhikode
# 6      Bangalore to Kannur (Kerala)
# 7             Kozhikode to Thrissur
# 8    Bangalore to Kalpetta (kerala)
# 9   Kozhikode to Thiruvananthapuram
# 10   Kalpetta (kerala) to Bangalore
# 11            Kozhikode to Kottayam
# 12     Kannur (Kerala) to Bangalore
# 13            Thrissur to Kozhikode
# 14  Thiruvananthapuram to Kozhikode
# 15            Kottayam to Kozhikode
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/bangalore-to...
# 1   https://www.redbus.in/bus-tickets/kozhikode-to...
# 2   https://www.redbus.in/bus-tickets/kozhikode-to...
# 3   https://www.redbus.in/bus-tickets/ernakulam-to...
# 4   https://www.redbus.in/bus-tickets/kozhikode-to...
# 5   https://www.redbus.in/bus-tickets/mysore-to-ko...
# 6   https://www.redbus.in/bus-tickets/bangalore-to...
# 7   https://www.redbus.in/bus-tickets/kozhikode-to...
# 8   https://www.redbus.in/bus-tickets/bangalore-to...
# 9   https://www.redbus.in/bus-tickets/kozhikode-to...
# 10  https://www.redbus.in/bus-tickets/kalpetta-to-...
# 11  https://www.redbus.in/bus-tickets/kozhikode-to...
# 12  https://www.redbus.in/bus-tickets/kannur-to-ba...
# 13  https://www.redbus.in/bus-tickets/thrissur-to-...
# 14  https://www.redbus.in/bus-tickets/thiruvananth...
# 15  https://www.redbus.in/bus-tickets/kottayam-to-...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_k = webdriver.Chrome(service=service)

# Lists to store the bus details
Bus_names_k = []
Bus_types_k = []
Start_Time_k = []
End_Time_k = []
Ratings_k = []
Total_Duration_k = []
Prices_k = []
Seats_Available_k = []
Route_names = []
Route_links = []

# Loop through the DataFrame rows to get bus details
for i, r in df_k.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    # Loop through each link
    driver_k.get(link)
    time.sleep(2)

    # Click on elements to reveal bus details
    elements = driver_k.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    # Click elements to view bus
    try:
        clicks = driver_k.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    # Scrolling to load additional bus details
    scrolling = True
    while scrolling:
        old_page_source = driver_k.page_source
        # Use ActionChains to perform PAGE_DOWN
        ActionChains(driver_k).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_k.page_source

        if new_page_source == old_page_source:
            scrolling = False

    # Extract bus details
    bus_name = driver_k.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_k.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_k.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_k.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_k.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    
    try:
        rating = driver_k.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    
    price = driver_k.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_k.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    # Append data to respective lists
    for bus in bus_name:
        Bus_names_k.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_k.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_k.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_k.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_k.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_k.append(ratings.text)
    for price_elem in price:
        Prices_k.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_k.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
#from list to convert data frame

data_1={
    'Bus_name':Bus_names_k,
    'Bus_type':Bus_types_k,
    'Start_time':Start_Time_k,
    'End_time':End_Time_k,
    'Total_Duration':Total_Duration_k,
    'Price':Prices_k,
    'Seats_Available':Seats_Available_k,
    'Ratings': Ratings_k,
    'Route_link':Route_links,
    'Route_name':Route_names
}


df_buses_K = pd.DataFrame(data_1)
#convert dataframe to csv
path = r"D:\guvi\redbus project\busdetails\df_buses_K.csv"
df_buses_K.to_csv(path,index=False)

# %%
df_buses_K
# Out:
#                   Bus_name                                   Bus_type  \
# 0     KSRTC (Kerala) - 581  Super Express Non AC Seater Air Bus (2+2)
# 1      KSRTC (Kerala) - 52                SWIFT-GARUDA A/C SEATER BUS
# 2    KSRTC (Kerala) - 1210     SWIFT-HYBRID NON AC SEATER CUM SLEEPER
# 3    KSRTC (Kerala) - 1378                              AC MULTI AXLE
# 4     KSRTC (Kerala) - 129                SWIFT-GARUDA A/C SEATER BUS
# ..                     ...                                        ...
# 271        Madhavi Travels                          A/C Sleeper (2+1)
# 272        Madhavi Travels               Volvo A/C Semi Sleeper (2+2)
# 273          Sonia Travels                   A/C Seater/Sleeper (2+1)
# 274            Ubc travels                   A/C Seater/Sleeper (2+1)
# 275             Cochin Bus              Bharat Benz A/C Sleeper (2+1)
#
#     Start_time End_time Total_Duration     Price     Seats_Available  \
# 0        10:00    18:40        08h 40m   INR 469   6 Seats available
# 1        12:00    20:20        08h 20m   INR 627  18 Seats available
# 2        12:55    21:05        08h 10m   INR 567  18 Seats available
# 3        13:46    21:25        07h 39m   INR 729  24 Seats available
# 4        14:15    23:05        08h 50m   INR 627  26 Seats available
# ..         ...      ...            ...       ...                 ...
# 271      18:50    03:00        08h 10m       999  18 Seats available
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/hyderabad-to...
# 1   https://www.redbus.in/bus-tickets/vijayawada-t...
# 2   https://www.redbus.in/bus-tickets/kakinada-to-...
# 3   https://www.redbus.in/bus-tickets/chittoor-and...
# 4   https://www.redbus.in/bus-tickets/hyderabad-to...
# 5   https://www.redbus.in/bus-tickets/ongole-to-hy...
# 6   https://www.redbus.in/bus-tickets/tirupathi-to...
# 7   https://www.redbus.in/bus-tickets/kadapa-to-ba...
# 8   https://www.redbus.in/bus-tickets/bangalore-to...
# 9   https://www.redbus.in/bus-tickets/bangalore-to...
# 10  https://www.redbus.in/bus-tickets/narsaraopet-...
# 11  https://www.redbus.in/bus-tickets/hyderabad-to...
# 12  https://www.redbus.in/bus-tickets/ananthapur-t...
# 13  https://www.redbus.in/bus-tickets/bangalore-to...
# 14  https://www.redbus.in/bus-tickets/madanapalli-...
# 15  https://www.redbus.in/bus-tickets/visakhapatna...
# 16  https://www.redbus.in/bus-tickets/vinukonda-to...
# 17  https://www.redbus.in/bus-tickets/bangalore-to...
# 18  https://www.redbus.in/bus-tickets/kadiri-to-ba...
# 19  https://www.redbus.in/bus-tickets/eluru-to-hyd...
# 20  https://www.redbus.in/bus-tickets/bangalore-to...
# 21  https://www.redbus.in/bus-tickets/guntur-to-hy...
# 22  https://www.redbus.in/bus-tickets/hyderabad-to...
# 23  https://www.redbus.in/bus-tickets/macherla-to-...
# 24  https://www.redbus.in/bus-tickets/bangalore-to...
# 25  https://www.redbus.in/bus-tickets/hyderabad-to...
# 26  https://www.redbus.in/bus-tickets/hyderabad-to...
# 27  https://www.redbus.in/bus-tickets/nandyala-to-...
# 28  https://www.redbus.in/bus-tickets/rayachoti-to...
# 29  https://www.redbus.in/bus-tickets/hyderabad-to...
# 30  https://www.redbus.in/bus-tickets/hyderabad-to...
# 31  https://www.redbus.in/bus-tickets/tirupathi-to...
# 32  https://www.redbus.in/bus-tickets/chennai-to-t...
# 33  https://www.redbus.in/bus-tickets/rajahmundry-...
# 34  https://www.redbus.in/bus-tickets/rajahmundry-...
# 35  https://www.redbus.in/bus-tickets/bangalore-to...
# 36  https://www.redbus.in/bus-tickets/kurnool-to-b...
# 37  https://www.redbus.in/bus-tickets/hyderabad-to...
# 38  https://www.redbus.in/bus-tickets/hyderabad-to...
# 39  https://www.redbus.in/bus-tickets/kurnool-to-h...
# 40  https://www.redbus.in/bus-tickets/kurnool-to-v...
# 41  https://www.redbus.in/bus-tickets/hyderabad-to...
# 42  https://www.redbus.in/bus-tickets/visakhapatna...
# 43  https://www.redbus.in/bus-tickets/rajahmundry-...
# 44  https://www.redbus.in/bus-tickets/chilakalurip...
# 45  https://www.redbus.in/bus-tickets/hyderabad-to...
# 46  https://www.redbus.in/bus-tickets/visakhapatna...
# 47  https://www.redbus.in/bus-tickets/hyderabad-to...
# 48  https://www.redbus.in/bus-tickets/markapuram-t...
# 49  https://www.redbus.in/bus-tickets/addanki-to-h...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_ap = webdriver.Chrome(service=service)

Bus_names_ap = []
Bus_types_ap = []
Start_Time_ap = []
End_Time_ap = []
Ratings_ap = []
Total_Duration_ap = []
Prices_ap = []
Seats_Available_ap = []
Route_names = []
Route_links = []

for i, r in df_AP.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_ap.get(link)
    time.sleep(2)

    elements = driver_ap.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_ap.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_ap.page_source
        ActionChains(driver_ap).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_ap.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_ap.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_ap.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_ap.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_ap.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_ap.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_ap.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_ap.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_ap.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_ap.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_ap.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_ap.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_ap.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_ap.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_ap.append(ratings.text)
    for price_elem in price:
        Prices_ap.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_ap.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_2 = {
    'Bus_name': Bus_names_ap,
    'Bus_type': Bus_types_ap,
    'Start_time': Start_Time_ap,
    'End_time': End_Time_ap,
    'Total_Duration': Total_Duration_ap,
    'Price': Prices_ap,
    'Seats_Available': Seats_Available_ap,
    'Ratings': Ratings_ap,
    'Route_link': Route_links,
    'Route_name': Route_names
}




df_buses_AP = pd.DataFrame(data_2)
#convert dataframe to csv
path = r"D:\guvi\redbus project\busdetails\df_buses_AP.csv"
df_buses_AP.to_csv(path,index=False)

# %%
df_buses_AP
# Out:
#                                 Bus_name  \
# 0                          APSRTC - 3858
# 1                          APSRTC - 9356
# 2                         APSRTC - 35269
# 3                          APSRTC - 3601
# 4                         APSRTC - 35117
# ..                                   ...
# 596  Sri Vengamamba Bus Transport (SVBT)
# 597             Orange Tours And Travels
# 598                     V Kaveri Travels
# 599                       Vikram Travels
# 600                     V Kaveri Travels
#
#                                            Bus_type Start_time End_time  \
# 0    DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)      11:30    16:30
# 1            SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
hyderabad to Addanki
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/hyderabad-to...
# 1   https://www.redbus.in/bus-tickets/khammam-to-h...
# 2   https://www.redbus.in/bus-tickets/hyderabad-to...
# 3   https://www.redbus.in/bus-tickets/hyderabad-to...
# 4   https://www.redbus.in/bus-tickets/karimnagar-t...
# 5   https://www.redbus.in/bus-tickets/guntur-to-hy...
# 6   https://www.redbus.in/bus-tickets/hyderabad-to...
# 7   https://www.redbus.in/bus-tickets/hyderabad-to...
# 8   https://www.redbus.in/bus-tickets/hyderabad-to...
# 9   https://www.redbus.in/bus-tickets/kothagudem-t...
# 10  https://www.redbus.in/bus-tickets/godavarikhan...
# 11  https://www.redbus.in/bus-tickets/hyderabad-to...
# 12  https://www.redbus.in/bus-tickets/hyderabad-to...
# 13  https://www.redbus.in/bus-tickets/hyderabad-to...
# 14  https://www.redbus.in/bus-tickets/jagityal-to-...
# 15  https://www.redbus.in/bus-tickets/hyderabad-to...
# 16  https://www.redbus.in/bus-tickets/hyderabad-to...
# 17  https://www.redbus.in/bus-tickets/hyderabad-to...
# 18  https://www.redbus.in/bus-tickets/hyderabad-to...
# 19  https://www.redbus.in/bus-tickets/kodad-to-hyd...
# 20  https://www.redbus.in/bus-tickets/hyderabad-to...
# 21  https://www.redbus.in/bus-tickets/hyderabad-to...
# 22  https://www.redbus.in/bus-tickets/hyderabad-to...
# 23  https://www.redbus.in/bus-tickets/hyderabad-to...
# 24  https://www.redbus.in/bus-tickets/hyderabad-to...
# 25  https://www.redbus.in/bus-tickets/hyderabad-to...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_t = webdriver.Chrome(service=service)

Bus_names_t = []
Bus_types_t = []
Start_Time_t = []
End_Time_t = []
Ratings_t = []
Total_Duration_t = []
Prices_t = []
Seats_Available_t = []
Route_names = []
Route_links = []

for i, r in df_T.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_t.get(link)
    time.sleep(2)

    elements = driver_t.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_t.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_t.page_source
        ActionChains(driver_t).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_t.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_t.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_t.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_t.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_t.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_t.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_t.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_t.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_t.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_t.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_t.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_t.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_t.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_t.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_t.append(ratings.text)
    for price_elem in price:
        Prices_t.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_t.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_3 = {
    'Bus_name': Bus_names_t,
    'Bus_type': Bus_types_t,
    'Start_time': Start_Time_t,
    'End_time': End_Time_t,
    'Total_Duration': Total_Duration_t,
    'Price': Prices_t,
    'Seats_Available': Seats_Available_t,
    'Ratings': Ratings_t,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_T = pd.DataFrame(data_3)
# Convert DataFrame to CSV
path = r"D:\guvi\redbus project\busdetails\df_buses_T.csv"
df_buses_T.to_csv(path, index=False)

# %%
df_buses_T
# Out:
#                                 Bus_name  \
# 0                          TGSRTC - 8726
# 1                          TGSRTC - 8847
# 2                          TGSRTC - 8970
# 3                         TGSRTC - 34339
# 4                          TGSRTC - 8706
# ..                                   ...
# 306  Sri Vengamamba Bus Transport (SVBT)
# 307  Sri Vengamamba Bus Transport (SVBT)
# 308                         KMBT Travels
# 309                       Chandu Travels
# 310                         Mozo travels
#
#                                        Bus_type Start_time End_time  \
# 0    Super Luxury (Non AC Seater 2+2 Push Back)      10:40    15:10
# 1    Super Luxury (Non AC Seater 2+2 Push Back)      11:10    15:30
# 2    Super Luxury (Non AC Seater 2+2 Push Back)      11:15    15:15
# 3                  RAJDHANI (A.C. Semi Sleeper)      11:20    15:30
# 4    Super Luxury (Non AC Seater 2+2 Push Back)      11:45    16:00
# ..                                          ...        ...      ...
# 306                  A/C Seater / Sleeper (2+1)      21:45    05:30
# 307                           A/C Sleeper (2+1)      21:40    05:30
# 308             NON A/C Hi-Tech Push Back (2+2)      21:10    05:00
# 309                           A/C Sleeper (2+1)      22:00    05:15
# 310                           A/C Sleeper (2+1)      22:00    04:30
#
#     Total_Duration    Price     Seats_Available  Ratings  \
# 0          04h 30m  INR 320  31 Seats available  3.8\n10
# 1          04h 20m  INR 320  31 Seats available   4.2\n8
# 2          04h 00m  INR 320  31 Seats available  4.0\n15
# 3          04h 10m  INR 350  35 Seats available  2.2\n31
# 4          04h 15m  INR 320  26 Seats available      3.7
# ..             ...      ...                 ...      ...
# 306        07h 45m  INR 642  20 Seats available  4.6\n60
# 307        07h 50m  INR 936  11 Seats available  4.3\n40
# 308        07h 50m      428  28 Seats available  4.1\n42
# 309        07h 15m      637  25 Seats available  4.2\n34
# 310        06h 30m  INR 800  18 Seats available  4.9\n13
#
#                                             Route_link            Route_name
# 0    https://www.redbus.in/bus-tickets/khammam-to-h...  Khammam to Hyderabad
# 1    https://www.redbus.in/bus-tickets/khammam-to-h...  Khammam to Hyderabad
# 2    https://www.redbus.in/bus-tickets/khammam-to-h...  Khammam to Hyderabad
# 3    https://www.redbus.in/bus-tickets/khammam-to-h...  Khammam to Hyderabad
# 4    https://www.redbus.in/bus-tickets/khammam-to-h...  Khammam to Hyderabad
# ..                                                 ...                   ...
# 306  https://www.redbus.in/bus-tickets/hyderabad-to...  Hyderabad to Addanki
# 307  https://www.redbus.in/bus-tickets/hyderabad-to...  Hyderabad to Addanki
# 308  https://www.redbus.in/bus-tickets/hyderabad-to...  Hyderabad to Addanki
# 309  https://www.redbus.in/bus-tickets/hyderabad-to...  Hyderabad to Addanki
# 310  https://www.redbus.in/bus-tickets/hyderabad-to...  Hyderabad to Addanki
#
# [311 rows x 10 columns]

# %%
df_KM=pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\kadamba_routes.csv')
df_KM
# Out:
#                          Route_name  \
# 0                       Pune to Goa
# 1                       Goa to Pune
# 2                     Mumbai to Goa
# 3                  Bangalore to Goa
# 4                   Belagavi to Goa
# 5                     Goa to Mumbai
# 6                  Goa to Bangalore
# 7                   Goa to Belagavi
# 8                 Pandharpur to Goa
# 9                    Solapur to Goa
# 10     Goa to Kolhapur(Maharashtra)
# 11                Goa to Pandharpur
# 12                   Goa to Solapur
# 13   Calangute (goa) to Goa Airport
# 14         Goa to Sangola (Solapur)
# 15   Goa Airport to Calangute (goa)
# 16         Sangola (Solapur) to Goa
# 17  Calangute (goa) to Mopa Airport
# 18                Ponda to Belagavi
# 19                Belagavi to Ponda
# 20                Shivamogga to Goa
# 21  Mopa Airport to Calangute (goa)
# 22               Marcel to Belagavi
# 23                    Goa to Sangli
# 24               Belagavi to Marcel
# 25            Panaji to Goa Airport
# 26              Goa to Mopa Airport
# 27                Goa to Shivamogga
# 28                     Goa to Miraj
# 29           Margao to Mopa Airport
# 30           Mopa Airport to Margao
# 31              Mopa Airport to Goa
# 32             Saquelim to Belagavi
# 33           Panaji to Mopa Airport
# 34                    Shirdi to Goa
# 35            Goa Airport to Panaji
# 36             Belagavi to Saquelim
# 37                    Goa to Satara
# 38           Mopa Airport to Panaji
# 39                    Goa to Shirdi
#
#                                            Route_link
# 0       https://www.redbus.in/bus-tickets/pune-to-goa
# 1       https://www.redbus.in/bus-tickets/goa-to-pune
# 2     https://www.redbus.in/bus-tickets/mumbai-to-goa
# 3   https://www.redbus.in/bus-tickets/bangalore-to...
# 4   https://www.redbus.in/bus-tickets/belagavi-to-goa
# 5     https://www.redbus.in/bus-tickets/goa-to-mumbai
# 6   https://www.redbus.in/bus-tickets/goa-to-banga...
# 7   https://www.redbus.in/bus-tickets/goa-to-belagavi
# 8   https://www.redbus.in/bus-tickets/pandharpur-t...
# 9    https://www.redbus.in/bus-tickets/solapur-to-goa
# 10  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 11  https://www.redbus.in/bus-tickets/goa-to-pandh...
# 12   https://www.redbus.in/bus-tickets/goa-to-solapur
# 13  https://www.redbus.in/bus-tickets/calangute-go...
# 14   https://www.redbus.in/bus-tickets/goa-to-sangola
# 15  https://www.redbus.in/bus-tickets/goa-airport-...
# 16   https://www.redbus.in/bus-tickets/sangola-to-goa
# 17  https://www.redbus.in/bus-tickets/calangute-go...
# 18  https://www.redbus.in/bus-tickets/ponda-to-bel...
# 19  https://www.redbus.in/bus-tickets/belagavi-to-...
# 20   https://www.redbus.in/bus-tickets/shimoga-to-goa
# 21  https://www.redbus.in/bus-tickets/mopa-airport...
# 22  https://www.redbus.in/bus-tickets/marcel-to-be...
# 23    https://www.redbus.in/bus-tickets/goa-to-sangli
# 24  https://www.redbus.in/bus-tickets/belagavi-to-...
# 25  https://www.redbus.in/bus-tickets/panaji-to-go...
# 26  https://www.redbus.in/bus-tickets/goa-to-mopa-...
# 27   https://www.redbus.in/bus-tickets/goa-to-shimoga
# 28     https://www.redbus.in/bus-tickets/goa-to-miraj
# 29  https://www.redbus.in/bus-tickets/margoa-to-mo...
# 30  https://www.redbus.in/bus-tickets/mopa-airport...
# 31  https://www.redbus.in/bus-tickets/mopa-airport...
# 32  https://www.redbus.in/bus-tickets/saquelim-to-...
# 33  https://www.redbus.in/bus-tickets/panaji-to-mo...
# 34    https://www.redbus.in/bus-tickets/shirdi-to-goa
# 35  https://www.redbus.in/bus-tickets/goa-airport-...
# 36  https://www.redbus.in/bus-tickets/belagavi-to-...
# 37    https://www.redbus.in/bus-tickets/goa-to-satara
# 38  https://www.redbus.in/bus-tickets/mopa-airport...
# 39    https://www.redbus.in/bus-tickets/goa-to-shirdi

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_km = webdriver.Chrome(service=service)

Bus_names_km = []
Bus_types_km = []
Start_Time_km = []
End_Time_km = []
Ratings_km = []
Total_Duration_km = []
Prices_km = []
Seats_Available_km = []
Route_names = []
Route_links = []

for i, r in df_KM.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_km.get(link)
    time.sleep(2)

    elements = driver_km.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_km.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_km.page_source
        ActionChains(driver_km).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_km.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_km.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_km.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_km.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_km.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_km.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_km.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_km.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_km.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_km.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_km.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_km.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_km.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_km.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_km.append(ratings.text)
    for price_elem in price:
        Prices_km.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_km.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_4 = {
    'Bus_name': Bus_names_km,
    'Bus_type': Bus_types_km,
    'Start_time': Start_Time_km,
    'End_time': End_Time_km,
    'Total_Duration': Total_Duration_km,
    'Price': Prices_km,
    'Seats_Available': Seats_Available_km,
    'Ratings': Ratings_km,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_KM = pd.DataFrame(data_4)
# Convert DataFrame to CSV
path = r"D:\guvi\redbus project\busdetails\df_buses_KM.csv"
df_buses_KM.to_csv(path, index=False)

# %%
df_buses_KM
# Out:
#                                              Bus_name  \
# 0   Kadamba Transport Corporation Limited (KTCL) -...
# 1   Kadamba Transport Corporation Limited (KTCL) -...
# 2                                      Ashray Travels
# 3                               Prasanna - Purple Bus
# 4                             Ashray National Express
# 5                                        Ashray Grand
# 6                                   IntrCity SmartBus
# 7   Kadamba Transport Corporation Limited (KTCL) -...
# 8   Kadamba Transport Corporation Limited (KTCL) -...
# 9                                       Atmaram Gobus
# 10                              Prasanna - Purple Bus
# 11                              Prasanna - Purple Bus
# 12                         Sangitam Travels Tanzanite
# 13                                  IntrCity SmartBus
# 14                                     Ashray Travels
# 15                                       Zingbus Plus
# 16                                       Zingbus Plus
# 17                                      Atmaram Gobus
# 18                                      Atmaram Gobus
# 19  Kadamba Transport Corporation Limited (KTCL) -...
# 20  Kadamba Transport Corporation Limited (KTCL) -...
# 21                                     Ashoka Travels
# 22                                  URL Travels Neeta
# 23                                KTC Travels (Neeta)
# 24                            Khurana Travel Services
# 25                                     Sharma Travels
# 26                                     Sharma Travels
# 27                                       Zingbus Plus
# 28                                  IntrCity SmartBus
# 29                                  IntrCity SmartBus
# 30                                     Ashray Travels
#
#                                  Bus_type Start_time End_time Total_Duration  \
# 0                       Non AC Seater 2+2      18:30    06:30        12h 00m
# 1                       A/C Sleeper (2+1)      19:00    07:10        12h 10m
# 2          Non A/C Seater / Sleeper (2+1)      21:15    09:40        12h 25m
# 3                    VE A/C Sleeper (2+1)      22:30    09:30        11h 00m
# 4                   NON A/C Sleeper (2+1)      20:00    07:00        11h 00m
# 5      Volvo Multi-Axle A/C Sleeper (2+1)      23:00    10:45        11h 45m
# 6   Bharat Benz A/C Seater /Sleeper (2+1)      21:15    07:55        10h 40m
# 7                       Non AC Seater 2+2      18:00    08:00        14h 00m
# 8                       A/C Sleeper (2+1)      19:00    07:00        12h 00m
# 9                   NON A/C Sleeper (2+1)      19:01    05:31        10h 30m
# 10                   VE A/C Sleeper (2+1)      17:00    05:00        12h 00m
# 11                   VE A/C Sleeper (2+1)      22:00    07:30        09h 30m
# 12                      A/C Sleeper (2+1)      21:00    07:30        10h 30m
# 13  Bharat Benz A/C Seater /Sleeper (2+1)      20:30    06:45        10h 15m
# 10      https://www.redbus.in/bus-tickets/goa-to-pune
# 11      https://www.redbus.in/bus-tickets/goa-to-pune
# 12      https://www.redbus.in/bus-tickets/goa-to-pune
# 13      https://www.redbus.in/bus-tickets/goa-to-pune
# 14      https://www.redbus.in/bus-tickets/goa-to-pune
# 15      https://www.redbus.in/bus-tickets/goa-to-pune
# 16      https://www.redbus.in/bus-tickets/goa-to-pune
# 17      https://www.redbus.in/bus-tickets/goa-to-pune
# 18      https://www.redbus.in/bus-tickets/goa-to-pune
# 19  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 20  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 21  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 22  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 23  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 24  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 25  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 26  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 27  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 28  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 29  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 30  https://www.redbus.in/bus-tickets/goa-to-kolha...
#
#                       Route_name
# 0                    Pune to Goa
# 1                    Pune to Goa
# 2                    Pune to Goa
# 3                    Pune to Goa
# 4                    Pune to Goa
# 5                    Pune to Goa
# 6                    Pune to Goa
# 7                    Goa to Pune
# 8                    Goa to Pune
# 9                    Goa to Pune
# 10                   Goa to Pune
# 11                   Goa to Pune
# 12                   Goa to Pune
# 13                   Goa to Pune
# 14                   Goa to Pune
# 15                   Goa to Pune
# 16                   Goa to Pune
# 17                   Goa to Pune
# 18                   Goa to Pune
# 19  Goa to Kolhapur(Maharashtra)
# 20  Goa to Kolhapur(Maharashtra)
# 21  Goa to Kolhapur(Maharashtra)
# 22  Goa to Kolhapur(Maharashtra)
# 23  Goa to Kolhapur(Maharashtra)
# 24  Goa to Kolhapur(Maharashtra)
# 25  Goa to Kolhapur(Maharashtra)
# 26  Goa to Kolhapur(Maharashtra)
# 27  Goa to Kolhapur(Maharashtra)
# 28  Goa to Kolhapur(Maharashtra)
# 29  Goa to Kolhapur(Maharashtra)
# 30  Goa to Kolhapur(Maharashtra)

# %%
df_R=pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\rajasthan_routes.csv')
df_R
# Out:
#                                        Route_name  \
# 0                                Jodhpur to Ajmer
# 1        Beawar (Rajasthan) to Jaipur (Rajasthan)
# 2                   Jaipur (Rajasthan) to Jodhpur
# 3                              Udaipur to Jodhpur
# 4                     Sikar to Jaipur (Rajasthan)
# 5   Aligarh (uttar pradesh) to Jaipur (Rajasthan)
# 6                Kishangarh to Jaipur (Rajasthan)
# 7           Kota(Rajasthan) to Jaipur (Rajasthan)
# 8                    Jaipur (Rajasthan) to Pilani
# 9                   Jodhpur to Beawar (Rajasthan)
# 10  Jaipur (Rajasthan) to Aligarh (uttar pradesh)
# 11                     Kota(Rajasthan) to Udaipur
# 12                               Sikar to Bikaner
# 13          Jaipur (Rajasthan) to Kota(Rajasthan)
# 14                    Udaipur to Pali (Rajasthan)
# 15                  Udaipur to Jaipur (Rajasthan)
# 16                               Bikaner to Sikar
# 17                 Jaipur (Rajasthan) to Bhilwara
# 18                    Pali (Rajasthan) to Udaipur
# 19                  Mathura to Jaipur (Rajasthan)
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 1   https://www.redbus.in/bus-tickets/beawer-to-ja...
# 2   https://www.redbus.in/bus-tickets/jaipur-to-jo...
# 3   https://www.redbus.in/bus-tickets/udaipur-to-j...
# 4   https://www.redbus.in/bus-tickets/sikar-to-jaipur
# 5   https://www.redbus.in/bus-tickets/aligarh-utta...
# 6   https://www.redbus.in/bus-tickets/kishangarh-t...
# 7   https://www.redbus.in/bus-tickets/kota-rajasth...
# 8   https://www.redbus.in/bus-tickets/jaipur-to-pi...
# 9   https://www.redbus.in/bus-tickets/jodhpur-to-b...
# 10  https://www.redbus.in/bus-tickets/jaipur-to-al...
# 11  https://www.redbus.in/bus-tickets/kota-rajasth...
# 12  https://www.redbus.in/bus-tickets/sikar-to-bik...
# 13  https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 14  https://www.redbus.in/bus-tickets/udaipur-to-p...
# 15  https://www.redbus.in/bus-tickets/udaipur-to-j...
# 16  https://www.redbus.in/bus-tickets/bikaner-to-s...
# 17  https://www.redbus.in/bus-tickets/jaipur-to-bh...
# 18  https://www.redbus.in/bus-tickets/pali-to-udaipur
# 19  https://www.redbus.in/bus-tickets/mathura-to-j...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_r = webdriver.Chrome(service=service)

Bus_names_r = []
Bus_types_r = []
Start_Time_r = []
End_Time_r = []
Ratings_r = []
Total_Duration_r = []
Prices_r = []
Seats_Available_r = []
Route_names = []
Route_links = []

for i, r in df_R.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_r.get(link)
    time.sleep(2)

    elements = driver_r.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_r.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_r.page_source
        ActionChains(driver_r).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_r.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_r.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_r.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_r.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_r.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_r.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_r.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_r.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_r.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_r.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_r.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_r.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_r.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_r.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_r.append(ratings.text)
    for price_elem in price:
        Prices_r.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_r.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_5 = {
    'Bus_name': Bus_names_r,
    'Bus_type': Bus_types_r,
    'Start_time': Start_Time_r,
    'End_time': End_Time_r,
    'Total_Duration': Total_Duration_r,
    'Price': Prices_r,
    'Seats_Available': Seats_Available_r,
    'Ratings': Ratings_r,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_R = pd.DataFrame(data_5)
# Convert DataFrame to CSV
path = r"D:\guvi\redbus project\busdetails\df_buses_R.csv"
df_buses_R.to_csv(path, index=False)

# %%
df_buses_R
# Out:
#                    Bus_name                                   Bus_type  \
# 0            RSRTC - 187798  Super Luxury Volvo AC Seater Pushback 2+2
# 1            RSRTC - 195911                  Express Non AC Seater 2+3
# 2            RSRTC - 194408                  Express Non AC Seater 2+3
# 3            RSRTC - 157455  Super Luxury Volvo AC Seater Pushback 2+2
# 4            RSRTC - 190571                  Express Non AC Seater 2+3
# ..                      ...                                        ...
# 249        UPSRTC - KSN0274                 Ordinary Non AC Seater 2+3
# 250           Rinku Travels                 A/C Seater / Sleeper (2+1)
# 251                GV Tours                 A/C Seater / Sleeper (2+1)
# 252  Bhagwati Travel Agency                 A/C Seater / Sleeper (2+1)
# 253              Om Travels                NON AC Seater / Sleeper 2+1
#
#     Start_time End_time Total_Duration    Price     Seats_Available  Ratings  \
# 0        11:55    15:50        03h 55m  INR 460  36 Seats available  3.3\n24
# 1        12:00    16:30        04h 30m  INR 229  42 Seats available      3.8
# 2        12:35    17:05        04h 30m  INR 229  42 Seats available      3.8
# 3        13:00    17:00        04h 00m  INR 460  37 Seats available  4.4\n51
# 4        13:15    18:00        04h 45m  INR 229  42 Seats available   2.1\n5
# ..         ...      ...            ...      ...                 ...      ...
# 249      18:00    00:01        06h 01m  INR 289  52 Seats available      3.3
# 250      23:30    05:22        05h 52m  INR 400   5 Seats available  3.4\n45
# 251      21:15    04:00        06h 45m      475  40 Seats available  2.3\n20
# 252      22:40    04:40        06h 00m      449  27 Seats available  2.0\n12
# 253      23:00    04:29        05h 29m  INR 400  32 Seats available      2.8
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 1    https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 2    https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 3    https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 4    https://www.redbus.in/bus-tickets/jodhpur-to-a...
# ..                                                 ...
# 249  https://www.redbus.in/bus-tickets/mathura-to-j...
# 250  https://www.redbus.in/bus-tickets/mathura-to-j...
# 251  https://www.redbus.in/bus-tickets/mathura-to-j...
# 252  https://www.redbus.in/bus-tickets/mathura-to-j...
# 253  https://www.redbus.in/bus-tickets/mathura-to-j...
#
#                         Route_name
# 0                 Jodhpur to Ajmer
# 1                 Jodhpur to Ajmer
# 2                 Jodhpur to Ajmer
# 3                 Jodhpur to Ajmer
# 4                 Jodhpur to Ajmer
# ..                             ...
# 249  Mathura to Jaipur (Rajasthan)
# 250  Mathura to Jaipur (Rajasthan)
# 251  Mathura to Jaipur (Rajasthan)
# 252  Mathura to Jaipur (Rajasthan)
# 253  Mathura to Jaipur (Rajasthan)
#
# [254 rows x 10 columns]

# %%
df_SB=pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\bengal_routes.csv')
df_SB
# Out:
#                                            Route_name  \
# 0                   Durgapur (West Bengal) to Kolkata
# 1                                  Kolkata to Burdwan
# 2                   Kolkata to Durgapur (West Bengal)
# 3                                   Haldia to Kolkata
# 4                                   Kolkata to Haldia
# 5                                Midnapore to Kolkata
# 6                   Kolkata to Arambagh (West Bengal)
# 7                                Kolkata to Midnapore
# 8                                    Kolkata to Digha
# 9                    Kolkata to Asansol (West Bengal)
# 10                                 Kolkata to Bankura
# 11                                Jhargram to Kolkata
# 12                                   Digha to Kolkata
# 13                                Kolkata to Nimtouri
# 14                         Kolkata to Contai (Kanthi)
# 15                    Digha to Durgapur (West Bengal)
# 16                Kolkata to Nandakumar (west bengal)
# 17                                Kolkata to Kolaghat
# 18                                    Kolkata to Suri
# 19                  Kirnahar (West Bengal) to Kolkata
# 20                   Kolkata to Mecheda (West Bengal)
# 21    Durgapur (West Bengal) to Barasat (West Bengal)
# 22                    Durgapur (West Bengal) to Digha
# 23                              Illambazar to Kolkata
# 24                  Purulia to Durgapur (West Bengal)
# 25  Durgapur (West Bengal) to Berhampore (West Ben...
# 26                 Midnapore to Barasat (West Bengal)
# 27                 Kolkata to Chandipur (West Bengal)
# 28                                   Kolkata to Debra
# 29  Berhampore (West Bengal) to Durgapur (West Ben...
# 30                                Kolkata to Panskura
# 31                 Barasat (West Bengal) to Midnapore
# 32                                Kolkata to Jhargram
# 33                     Digha to Barasat (West Bengal)
# 34                  Kolkata to Kirnahar (West Bengal)
# 35                  Kirnahar (West Bengal) to Burdwan
# 36   Berhampore (West Bengal) to Bolpur (West Bengal)
# 37                                   Kolkata to Heria
# 38                              Futishanko to Kolkata
# 39                  Kolkata to Ramnagar (West Bengal)
# 40                                  Kolkata to Ashari
# 41                                 Kolkata to Purulia
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/durgapur-to-...
# 1   https://www.redbus.in/bus-tickets/kolkata-to-b...
# 2   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 3   https://www.redbus.in/bus-tickets/haldia-to-ko...
# 4   https://www.redbus.in/bus-tickets/kolkata-to-h...
# 5   https://www.redbus.in/bus-tickets/midnapore-to...
# 6   https://www.redbus.in/bus-tickets/kolkata-to-a...
# 7   https://www.redbus.in/bus-tickets/kolkata-to-m...
# 8   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 9   https://www.redbus.in/bus-tickets/kolkata-to-a...
# 10  https://www.redbus.in/bus-tickets/kolkata-to-b...
# 11  https://www.redbus.in/bus-tickets/jhargram-to-...
# 12  https://www.redbus.in/bus-tickets/digha-to-kol...
# 13  https://www.redbus.in/bus-tickets/kolkata-to-n...
# 14  https://www.redbus.in/bus-tickets/kolkata-to-c...
# 15  https://www.redbus.in/bus-tickets/digha-to-dur...
# 16  https://www.redbus.in/bus-tickets/kolkata-to-n...
# 17  https://www.redbus.in/bus-tickets/kolkata-to-k...
# 18  https://www.redbus.in/bus-tickets/kolkata-to-suri
# 19  https://www.redbus.in/bus-tickets/kirnahar-wes...
# 20  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 21  https://www.redbus.in/bus-tickets/durgapur-to-...
# 22  https://www.redbus.in/bus-tickets/durgapur-to-...
# 23  https://www.redbus.in/bus-tickets/illambazar-t...
# 24  https://www.redbus.in/bus-tickets/purulia-to-d...
# 25  https://www.redbus.in/bus-tickets/durgapur-to-...
# 26  https://www.redbus.in/bus-tickets/midnapore-to...
# 27  https://www.redbus.in/bus-tickets/kolkata-to-c...
# 28  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 29  https://www.redbus.in/bus-tickets/berhampore-t...
# 30  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 31  https://www.redbus.in/bus-tickets/barasat-west...
# 32  https://www.redbus.in/bus-tickets/kolkata-to-j...
# 33  https://www.redbus.in/bus-tickets/digha-to-bar...
# 34  https://www.redbus.in/bus-tickets/kolkata-to-k...
# 35  https://www.redbus.in/bus-tickets/kirnahar-wes...
# 36  https://www.redbus.in/bus-tickets/berhampore-t...
# 37  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 38  https://www.redbus.in/bus-tickets/futishanko-t...
# 39  https://www.redbus.in/bus-tickets/kolkata-to-r...
# 40  https://www.redbus.in/bus-tickets/kolkata-to-a...
# 41  https://www.redbus.in/bus-tickets/kolkata-to-p...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_sb = webdriver.Chrome(service=service)

Bus_names_sb = []
Bus_types_sb = []
Start_Time_sb = []
End_Time_sb = []
Ratings_sb = []
Total_Duration_sb = []
Prices_sb = []
Seats_Available_sb = []
Route_names = []
Route_links = []

for i, r in df_SB.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_sb.get(link)
    time.sleep(2)

    elements = driver_sb.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_sb.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_sb.page_source
        ActionChains(driver_sb).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_sb.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_sb.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_sb.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_sb.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_sb.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_sb.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_sb.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_sb.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_sb.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_sb.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_sb.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_sb.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_sb.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_sb.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_sb.append(ratings.text)
    for price_elem in price:
        Prices_sb.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_sb.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_6 = {
    'Bus_name': Bus_names_sb,
    'Bus_type': Bus_types_sb,
    'Start_time': Start_Time_sb,
    'End_time': End_Time_sb,
    'Total_Duration': Total_Duration_sb,
    'Price': Prices_sb,
    'Seats_Available': Seats_Available_sb,
    'Ratings': Ratings_sb,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_SB = pd.DataFrame(data_6)
# Convert DataFrame to CSV
path = r"D:\guvi\redbus project\busdetails\df_buses_SB.csv"
df_buses_SB.to_csv(path, index=False)

# %%
df_buses_SB
# Out:
#                                               Bus_name             Bus_type  \
# 0    SBSTC-DURGAPUR - KARUNAMOYEE - 11:45 (DGP DEPO...  Non AC Seater (2+3)
# 1    SBSTC-DURGAPUR - KOLKATA - 12:00 (DGP DEPOT) -...  Non AC Seater (2+3)
# 2    SBSTC-BANKURA - KARUNAMOYEE - 10:15 (BNK DEPOT...  Non AC Seater (2+3)
# 3    SBSTC-DURGAPUR - KARUNAMOYEE - 12:15 (DGP DEPO...  Non AC Seater (2+3)
# 4    SBSTC-ASANSOL - KOLKATA - L/S - 11:10 (ASANSOL...  Non AC Seater (2+3)
# ..                                                 ...                  ...
# 155  SBSTC-KOLKATA - PURULIA - VIA - BANKURA - 13:0...  Non AC Seater (2+3)
# 156  SBSTC-KOLKATA - PURULIA - VIA - ASN - 14:15 (P...  Non AC Seater (2+3)
# 157
# 158
# 159
#
#     Start_time End_time Total_Duration    Price     Seats_Available  Ratings  \
# 0        11:45    15:45        04h 00m  INR 155  34 Seats available  4.4\n82
# 1        12:00    15:30        03h 30m  INR 150  52 Seats available  3.9\n40
# 2        12:00    16:00        04h 00m  INR 155  35 Seats available  3.7\n71
# 3        12:15    16:15        04h 00m  INR 155  43 Seats available      3.6
# 4        12:20    15:50        03h 30m  INR 150  48 Seats available  3.8\n13
# ..         ...      ...            ...      ...                 ...      ...
# 155      13:00    19:30        06h 30m  INR 250  48 Seats available  2.5\n31
# 156      14:15    20:45        06h 30m  INR 250  48 Seats available  3.7\n10
# 157
# 158
# 159
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/durgapur-to-...
# 1    https://www.redbus.in/bus-tickets/durgapur-to-...
# 2    https://www.redbus.in/bus-tickets/durgapur-to-...
# 3    https://www.redbus.in/bus-tickets/durgapur-to-...
# 4    https://www.redbus.in/bus-tickets/durgapur-to-...
# ..                                                 ...
# 155  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 156  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 157  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 158  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 159  https://www.redbus.in/bus-tickets/kolkata-to-p...
#
#                             Route_name
# 0    Durgapur (West Bengal) to Kolkata
# 1    Durgapur (West Bengal) to Kolkata
# 2    Durgapur (West Bengal) to Kolkata
# 3    Durgapur (West Bengal) to Kolkata
# 4    Durgapur (West Bengal) to Kolkata
# ..                                 ...
# 155                 Kolkata to Purulia
# 156                 Kolkata to Purulia
# 157                 Kolkata to Purulia
# 158                 Kolkata to Purulia
# 159                 Kolkata to Purulia
#
# [160 rows x 10 columns]

# %%
df_H=pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\himachal_routes.csv')
df_H
# Out:
#                                        Route_name  \
# 0                                 Delhi to Shimla
# 1                                 Shimla to Delhi
# 2       Hamirpur (Himachal Pradesh) to Chandigarh
# 3       Chandigarh to Hamirpur (Himachal Pradesh)
# 4            Hamirpur (Himachal Pradesh) to Delhi
# 5                             Delhi to Chandigarh
# 6         Chamba (Himachal Pradesh) to Chandigarh
# 7                            Kangra to Chandigarh
# 8    Dharamshala (Himachal Pradesh) to Chandigarh
# 9            Delhi to Hamirpur (Himachal Pradesh)
# 10                           Manali to Chandigarh
# 11                               Shimla to Manali
# 12                         Palampur to Chandigarh
# 13                              Delhi to Nalagarh
# 14                           Chandigarh to Manali
# 15                           Shimla to Chandigarh
# 16                        Ghumarwin to Chandigarh
# 17                                 Delhi to Solan
# 18             Chamba (Himachal Pradesh) to Delhi
# 19   Chandigarh to Dharamshala (Himachal Pradesh)
# 20                                 Solan to Delhi
# 21                              Palampur to Delhi
# 22                                Delhi to Manali
# 23                                Kullu to Shimla
# 24             Delhi to Chamba (Himachal Pradesh)
# 25                               Manali to Shimla
# 26                                Kangra to Delhi
# 27                                Manali to Delhi
# 28  Sunder Nagar (Himachal Pradesh) to Chandigarh
# 29                             Ghumarwin to Delhi
# 30                           Jassur to Chandigarh
# 31                            Chandigarh to Kullu
# 32              Baddi (Himachal Pradesh) to Delhi
# 33   Chandigarh to Reckong Peo (Himachal Pradesh)
# 34                           Chandigarh to Kangra
# 35           Delhi to Bilaspur (Himachal Pradesh)
# 36                         Baijnath to Chandigarh
# 37                             Shimla to Dehradun
# 38                             Sarkaghat to Delhi
# 39        Dharamshala (Himachal Pradesh) to Delhi
# 40                                  Jahu to Delhi
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/delhi-to-shimla
# 1   https://www.redbus.in/bus-tickets/shimla-to-delhi
# 2   https://www.redbus.in/bus-tickets/hamirpur-him...
# 3   https://www.redbus.in/bus-tickets/chandigarh-t...
# 4   https://www.redbus.in/bus-tickets/hamirpur-him...
# 5   https://www.redbus.in/bus-tickets/delhi-to-cha...
# 6   https://www.redbus.in/bus-tickets/chamba-himac...
# 7   https://www.redbus.in/bus-tickets/kangra-to-ch...
# 8   https://www.redbus.in/bus-tickets/dharamshala-...
# 9   https://www.redbus.in/bus-tickets/delhi-to-ham...
# 10  https://www.redbus.in/bus-tickets/manali-to-ch...
# 11  https://www.redbus.in/bus-tickets/shimla-to-ma...
# 12  https://www.redbus.in/bus-tickets/palampur-to-...
# 13  https://www.redbus.in/bus-tickets/delhi-to-nal...
# 14  https://www.redbus.in/bus-tickets/chandigarh-t...
# 15  https://www.redbus.in/bus-tickets/shimla-to-ch...
# 16  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 17   https://www.redbus.in/bus-tickets/delhi-to-solan
# 18  https://www.redbus.in/bus-tickets/chamba-himac...
# 19  https://www.redbus.in/bus-tickets/chandigarh-t...
# 20   https://www.redbus.in/bus-tickets/solan-to-delhi
# 21  https://www.redbus.in/bus-tickets/palampur-to-...
# 22  https://www.redbus.in/bus-tickets/delhi-to-manali
# 23  https://www.redbus.in/bus-tickets/kullu-to-shimla
# 24  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 25  https://www.redbus.in/bus-tickets/manali-to-sh...
# 26  https://www.redbus.in/bus-tickets/kangra-to-delhi
# 27  https://www.redbus.in/bus-tickets/manali-to-delhi
# 28  https://www.redbus.in/bus-tickets/sundernagar-...
# 29  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 30  https://www.redbus.in/bus-tickets/jassur-to-ch...
# 31  https://www.redbus.in/bus-tickets/chandigarh-t...
# 32  https://www.redbus.in/bus-tickets/baddi-himach...
# 33  https://www.redbus.in/bus-tickets/chandigarh-t...
# 34  https://www.redbus.in/bus-tickets/chandigarh-t...
# 35  https://www.redbus.in/bus-tickets/delhi-to-bil...
# 36  https://www.redbus.in/bus-tickets/baijnath-to-...
# 37  https://www.redbus.in/bus-tickets/shimla-to-de...
# 38  https://www.redbus.in/bus-tickets/sarkaghat-to...
# 39  https://www.redbus.in/bus-tickets/dharamshala-...
# 40   https://www.redbus.in/bus-tickets/jahoo-to-delhi

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_h = webdriver.Chrome(service=service)

Bus_names_h = []
Bus_types_h = []
Start_Time_h = []
End_Time_h = []
Ratings_h = []
Total_Duration_h = []
Prices_h = []
Seats_Available_h = []
Route_names = []
Route_links = []

for i, r in df_H.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_h.get(link)
    time.sleep(2)

    elements = driver_h.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_h.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_h.page_source
        ActionChains(driver_h).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_h.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_h.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_h.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_h.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_h.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_h.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_h.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_h.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_h.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_h.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_h.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_h.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_h.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_h.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_h.append(ratings.text)
    for price_elem in price:
        Prices_h.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_h.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_7 = {
    'Bus_name': Bus_names_h,
    'Bus_type': Bus_types_h,
    'Start_time': Start_Time_h,
    'End_time': End_Time_h,
    'Total_Duration': Total_Duration_h,
    'Price': Prices_h,
    'Seats_Available': Seats_Available_h,
    'Ratings': Ratings_h,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_H = pd.DataFrame(data_7)
# Convert DataFrame to CSV
path = r"D:\guvi\redbus project\busdetails\df_buses_H.csv"
df_buses_H.to_csv(path, index=False)

# %%
df_buses_H
# Out:
#        Bus_name                            Bus_type Start_time End_time  \
# 0    HRTC - 515          Ordinary 3+2 Non AC Seater      12:30    22:50
# 1    HRTC - 551                 A/C Executive (2+3)      15:30    01:30
# 2    HRTC - 525          Ordinary 3+2 Non AC Seater      16:50    03:00
# 3    HRTC - 532          Ordinary 3+2 Non AC Seater      17:59    04:15
# 4     HRTC - 93  Himsuta AC Seater Volvo/Scania 2+2      19:35    04:50
# ..          ...                                 ...        ...      ...
# 280
# 281
# 282
# 283
# 284
#
#     Total_Duration    Price     Seats_Available  Ratings  \
# 0          10h 20m  INR 512  37 Seats available   4.5\n4
# 1          10h 00m  INR 632  42 Seats available  2.6\n10
# 2          10h 10m  INR 512  27 Seats available      4.1
# 3          10h 16m  INR 512  27 Seats available   3.0\n5
# 4          09h 15m  INR 912  28 Seats available  4.6\n40
# ..             ...      ...                 ...      ...
# 280
# 281
# 282
# 283
# 284
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/delhi-to-shimla
# 1    https://www.redbus.in/bus-tickets/delhi-to-shimla
# 2    https://www.redbus.in/bus-tickets/delhi-to-shimla
# 3    https://www.redbus.in/bus-tickets/delhi-to-shimla
# 4    https://www.redbus.in/bus-tickets/delhi-to-shimla
# ..                                                 ...
# 280  https://www.redbus.in/bus-tickets/dharamshala-...
# 281  https://www.redbus.in/bus-tickets/dharamshala-...
# 282  https://www.redbus.in/bus-tickets/dharamshala-...
# 283  https://www.redbus.in/bus-tickets/dharamshala-...
# 284  https://www.redbus.in/bus-tickets/dharamshala-...
#
#                                   Route_name
# 0                            Delhi to Shimla
# 1                            Delhi to Shimla
# 2                            Delhi to Shimla
# 3                            Delhi to Shimla
# 4                            Delhi to Shimla
# ..                                       ...
# 280  Dharamshala (Himachal Pradesh) to Delhi
# 281  Dharamshala (Himachal Pradesh) to Delhi
# 282  Dharamshala (Himachal Pradesh) to Delhi
# 283  Dharamshala (Himachal Pradesh) to Delhi
# 284  Dharamshala (Himachal Pradesh) to Delhi
#
# [285 rows x 10 columns]

# %%
df_A=pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\assam_routes.csv')
df_A
# Out:
#                              Route_name  \
# 0                    Tezpur to Guwahati
# 1                    Guwahati to Tezpur
# 2            Nagaon (Assam) to Guwahati
# 3            Guwahati to Nagaon (Assam)
# 4                  Goalpara to Guwahati
# 5             Jorhat to North Lakhimpur
# 6   North Lakhimpur to Sibsagar (Assam)
# 7                    Guwahati to Dhubri
# 8                    Dhubri to Guwahati
# 9                Dhekiajuli to Guwahati
# 10  Sibsagar (Assam) to North Lakhimpur
# 11            North Lakhimpur to Jorhat
# 12                  Jorhat to Dibrugarh
# 13                    Jorhat to Dhemaji
# 14                   Jorhat to Tinsukia
# 15                    Dhemaji to Jorhat
# 16        Guwahati to Biswanath Charali
# 17                  Tezpur to Dibrugarh
# 18         North Lakhimpur to Dibrugarh
# 19            North Lakhimpur to Tezpur
# 20                  Dibrugarh to Jorhat
# 21          Sibsagar (Assam) to Dhemaji
# 22        Biswanath Charali to Guwahati
# 23                   Tinsukia to Jorhat
# 24         Dibrugarh to North Lakhimpur
# 25       Biswanath Charali to Dibrugarh
# 26                  Dibrugarh to Tezpur
# 27            Tezpur to North Lakhimpur
# 28       Dibrugarh to Biswanath Charali
# 29          Guwahati to North Lakhimpur
# 30                Bihpuria to Dibrugarh
# 31                Bokakhat to Dibrugarh
# 32                  Guwahati to Silchar
# 33             North Lakhimpur to Moran
# 34                 Guwahati to Kaliabor
# 35             Moran to North Lakhimpur
# 36                      Moran to Tezpur
# 37          Golaghat to North Lakhimpur
# 38                 Dergaon to Dibrugarh
# 39                   Gohpur to Guwahati
# 40    North Lakhimpur to Nagaon (Assam)
# 41          North Lakhimpur to Guwahati
# 42                   Jorhat to Gogamukh
# 43                   Tinsukia to Tezpur
# 44          North Lakhimpur to Golaghat
# 45                   Tezpur to Tinsukia
# 46    Nagaon (Assam) to North Lakhimpur
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/tezpur-to-gu...
# 1   https://www.redbus.in/bus-tickets/guwahati-to-...
# 2   https://www.redbus.in/bus-tickets/nagaon-to-gu...
# 3   https://www.redbus.in/bus-tickets/guwahati-to-...
# 4   https://www.redbus.in/bus-tickets/goalpara-to-...
# 5   https://www.redbus.in/bus-tickets/jorhat-to-no...
# 6   https://www.redbus.in/bus-tickets/north-lakhim...
# 7   https://www.redbus.in/bus-tickets/guwahati-to-...
# 8   https://www.redbus.in/bus-tickets/dhubri-to-gu...
# 9   https://www.redbus.in/bus-tickets/dhekiajuli-t...
# 10  https://www.redbus.in/bus-tickets/sibsagar-to-...
# 11  https://www.redbus.in/bus-tickets/north-lakhim...
# 12  https://www.redbus.in/bus-tickets/jorhat-to-di...
# 13  https://www.redbus.in/bus-tickets/jorhat-to-dh...
# 14  https://www.redbus.in/bus-tickets/jorhat-to-ti...
# 15  https://www.redbus.in/bus-tickets/dhemaji-to-j...
# 16  https://www.redbus.in/bus-tickets/guwahati-to-...
# 17  https://www.redbus.in/bus-tickets/tezpur-to-di...
# 18  https://www.redbus.in/bus-tickets/north-lakhim...
# 19  https://www.redbus.in/bus-tickets/north-lakhim...
# 20  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 21  https://www.redbus.in/bus-tickets/sibsagar-to-...
# 22  https://www.redbus.in/bus-tickets/biswanath-ch...
# 23  https://www.redbus.in/bus-tickets/tinsukia-to-...
# 24  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 25  https://www.redbus.in/bus-tickets/biswanath-ch...
# 26  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 27  https://www.redbus.in/bus-tickets/tezpur-to-no...
# 28  https://www.redbus.in/bus-tickets/dibrugarh-to...
# 29  https://www.redbus.in/bus-tickets/guwahati-to-...
# 30  https://www.redbus.in/bus-tickets/bihpuria-to-...
# 31  https://www.redbus.in/bus-tickets/bokakhat-to-...
# 32  https://www.redbus.in/bus-tickets/guwahati-to-...
# 33  https://www.redbus.in/bus-tickets/north-lakhim...
# 34  https://www.redbus.in/bus-tickets/guwahati-to-...
# 35  https://www.redbus.in/bus-tickets/moran-to-nor...
# 36  https://www.redbus.in/bus-tickets/moran-to-tezpur
# 37  https://www.redbus.in/bus-tickets/golaghat-to-...
# 38  https://www.redbus.in/bus-tickets/dergaon-to-d...
# 39  https://www.redbus.in/bus-tickets/gohpur-to-gu...
# 40  https://www.redbus.in/bus-tickets/north-lakhim...
# 41  https://www.redbus.in/bus-tickets/north-lakhim...
# 42  https://www.redbus.in/bus-tickets/jorhat-to-go...
# 43  https://www.redbus.in/bus-tickets/tinsukia-to-...
# 44  https://www.redbus.in/bus-tickets/north-lakhim...
# 45  https://www.redbus.in/bus-tickets/tezpur-to-ti...
# 46  https://www.redbus.in/bus-tickets/nagaon-to-no...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_a = webdriver.Chrome(service=service)

Bus_names_a = []
Bus_types_a = []
Start_Time_a = []
End_Time_a = []
Ratings_a = []
Total_Duration_a = []
Prices_a = []
Seats_Available_a = []
Route_names = []
Route_links = []

for i, r in df_A.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_a.get(link)
    time.sleep(2)

    elements = driver_a.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_a.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_a.page_source
        ActionChains(driver_a).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_a.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_a.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_a.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_a.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_a.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_a.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    
    try:
        rating = driver_a.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    
    price = driver_a.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_a.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_a.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_a.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_a.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_a.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_a.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_a.append(ratings.text)
    for price_elem in price:
        Prices_a.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_a.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
data_8 = {
    'Bus_name': Bus_names_a,
    'Bus_type': Bus_types_a,
    'Start_time': Start_Time_a,
    'End_time': End_Time_a,
    'Total_Duration': Total_Duration_a,
    'Price': Prices_a,
    'Seats_Available': Seats_Available_a,
    'Ratings': Ratings_a,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_A = pd.DataFrame(data_8)

path = r"D:\guvi\redbus project\busdetails\df_buses_A.csv"
df_buses_A.to_csv(path, index=False)

# %%
df_buses_A
# Out:
#                                              Bus_name  \
# 0   Assam State Transport Corporation (ASTC) - 154930
# 1   Assam State Transport Corporation (ASTC) - 139847
# 2                                Chartered Bus - ASTC
# 3                        Pranjit Travels (Under ASTC)
# 4                        Pranjit Travels (Under ASTC)
# 5                                      SHIVAM TRAVELS
# 6                                Chartered Bus - ASTC
# 7                     BLUE HILL TRAVELS INDIA LIMITED
# 8                     BLUE HILL TRAVELS INDIA LIMITED
# 9                                  Boithaboti Travels
# 10                                     PANKAJ TRAVELS
# 11                                       Maya Travels
#
#                              Bus_type Start_time End_time Total_Duration  \
# 0                 Volvo AC Seater 2+2      15:45    20:00        04h 15m
# 1                 Volvo AC Seater 2+2      16:15    20:30        04h 15m
# 2          A/C Seater Push Back (2+2)      11:30    16:15        04h 45m
# 3                NON A/C Seater (2+1)      11:30    16:45        05h 15m
# 4                NON A/C Seater (2+1)      11:45    16:45        05h 00m
# 5        Bharat Benz A/C Seater (2+1)      15:00    19:15        04h 15m
# 6        Volvo AC Seater Pushback 2+2      15:30    19:15        03h 45m
# 7   NON A/C Seater Semi Sleeper (2+1)      21:15    03:00        05h 45m
# 8   NON A/C Seater Semi Sleeper (2+1)      21:45    03:15        05h 30m
# 9          A/C Seater Push Back (2+2)      12:10    16:30        04h 20m
# 10                    AC Seater (2+2)      13:10    17:50        04h 40m
# 11              Tata A/C Seater (2+2)      13:00    17:30        04h 30m
#
#          Price     Seats_Available   Ratings  \
# 0      INR 298  18 Seats available   4.2\n86
# 1      INR 298  25 Seats available  4.1\n131
# 2   INR 397.08   3 Seats available  4.4\n142
# 3          405  14 Seats available   4.1\n25
# 4          405  25 Seats available       3.4
# 5      INR 350  27 Seats available  4.2\n245
# 6   INR 397.08   4 Seats available  4.5\n419
# 7      INR 450  24 Seats available   3.7\n89
# 8          450  26 Seats available   3.5\n25
# 9          270  24 Seats available       New
# 10         315   8 Seats available    2.4\n8
# 11     INR 300  39 Seats available   1.9\n21
#
#                                            Route_link          Route_name
# 0   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 1   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 2   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 3   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 4   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 5   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 6   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 7   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 8   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 9   https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 10  https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati
# 11  https://www.redbus.in/bus-tickets/tezpur-to-gu...  Tezpur to Guwahati

# %%
df_UP=pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\uttarpradesh_routes.csv')
df_UP
# Out:
#                                            Route_name  \
# 0                   Bareilly (Uttar Pradesh) to Delhi
# 1                   Delhi to Bareilly (Uttar Pradesh)
# 2                    Aligarh (uttar pradesh) to Delhi
# 3                                    Lucknow to Delhi
# 4                 Lucknow to Prayagraj(Uttar Pradesh)
# 5                Farrukhabad (Uttar Pradesh) to Delhi
# 6                 Prayagraj(Uttar Pradesh) to Lucknow
# 7                    Sitapur (Uttar Pradesh) to Delhi
# 8                Gorakhpur (uttar pradesh) to Lucknow
# 9                                     Agra to Lucknow
# 10                                    Lucknow to Agra
# 11                                 Moradabad to Delhi
# 12                                Varanasi to Lucknow
# 13               Delhi to Farrukhabad (Uttar Pradesh)
# 14                 Aligarh (uttar pradesh) to Lucknow
# 15                                Lucknow to Varanasi
# 16                   Delhi to Aligarh (uttar pradesh)
# 17                 Lucknow to Aligarh (uttar pradesh)
# 18                                   Delhi to Lucknow
# 19                  Ballia (Uttar Pradesh) to Lucknow
# 20                                 Lucknow to Mathura
# 21                                    Badaun to Delhi
# 22              Varanasi to Gorakhpur (uttar pradesh)
# 23              Shahjahanpur (Uttar Pradesh) to Delhi
# 24                 Kanpur (Uttar Pradesh) to Varanasi
# 25                 Gorakhpur (uttar pradesh) to Delhi
# 26                  Lucknow to Ballia (Uttar Pradesh)
# 27  Kanpur (Uttar Pradesh) to Bareilly (Uttar Prad...
# 28                Bareilly (Uttar Pradesh) to Lucknow
# 29               Bareilly (Uttar Pradesh) to Dehradun
# 30                   Agra to Bareilly (Uttar Pradesh)
# 31                Lucknow to Bareilly (Uttar Pradesh)
# 32                   Delhi to Sitapur (Uttar Pradesh)
# 33  Aligarh (uttar pradesh) to Greater noida (utta...
# 34                                    Delhi to Badaun
# 35               Lucknow to Gorakhpur (uttar pradesh)
# 36                   Bareilly (Uttar Pradesh) to Agra
# 37                                      Agra to Delhi
# 38                                  Pilibhit to Delhi
# 39                  Lucknow to Kanpur (Uttar Pradesh)
# 40                                 Delhi to Moradabad
# 41                                  Haldwani to Delhi
# 42                    Aligarh (uttar pradesh) to Agra
# 43               Varanasi to Prayagraj(Uttar Pradesh)
# 44                 Lakhimpur (uttar pradesh) to Delhi
# 45                               Lucknow to Moradabad
# 46               Prayagraj(Uttar Pradesh) to Varanasi
# 47                                  Delhi to Haridwar
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/bareilly-to-...
# 1   https://www.redbus.in/bus-tickets/delhi-to-bar...
# 2   https://www.redbus.in/bus-tickets/aligarh-utta...
# 3   https://www.redbus.in/bus-tickets/lucknow-to-d...
# 4   https://www.redbus.in/bus-tickets/lucknow-to-a...
# 5   https://www.redbus.in/bus-tickets/farrukhabad-...
# 6   https://www.redbus.in/bus-tickets/allahabad-to...
# 7   https://www.redbus.in/bus-tickets/sitapur-to-d...
# 8   https://www.redbus.in/bus-tickets/gorakhpur-to...
# 9   https://www.redbus.in/bus-tickets/agra-to-lucknow
# 10  https://www.redbus.in/bus-tickets/lucknow-to-agra
# 11  https://www.redbus.in/bus-tickets/moradabad-to...
# 12  https://www.redbus.in/bus-tickets/varanasi-to-...
# 13  https://www.redbus.in/bus-tickets/delhi-to-far...
# 14  https://www.redbus.in/bus-tickets/aligarh-to-l...
# 15  https://www.redbus.in/bus-tickets/lucknow-to-v...
# 16  https://www.redbus.in/bus-tickets/delhi-to-ali...
# 17  https://www.redbus.in/bus-tickets/lucknow-to-a...
# 18  https://www.redbus.in/bus-tickets/delhi-to-luc...
# 19  https://www.redbus.in/bus-tickets/ballia-to-lu...
# 20  https://www.redbus.in/bus-tickets/lucknow-to-m...
# 21  https://www.redbus.in/bus-tickets/badaun-to-delhi
# 22  https://www.redbus.in/bus-tickets/varanasi-to-...
# 23  https://www.redbus.in/bus-tickets/shahjahanpur...
# 24  https://www.redbus.in/bus-tickets/kanpur-to-va...
# 25  https://www.redbus.in/bus-tickets/gorakhpur-to...
# 26  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 27  https://www.redbus.in/bus-tickets/kanpur-to-ba...
# 28  https://www.redbus.in/bus-tickets/bareilly-to-...
# 29  https://www.redbus.in/bus-tickets/bareilly-to-...
# 30  https://www.redbus.in/bus-tickets/agra-to-bare...
# 31  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 32  https://www.redbus.in/bus-tickets/delhi-to-sit...
# 33  https://www.redbus.in/bus-tickets/aligarh-to-g...
# 34  https://www.redbus.in/bus-tickets/delhi-to-badaun
# 35  https://www.redbus.in/bus-tickets/lucknow-to-g...
# 36  https://www.redbus.in/bus-tickets/bareilly-to-...
# 37    https://www.redbus.in/bus-tickets/agra-to-delhi
# 38  https://www.redbus.in/bus-tickets/pilibhit-to-...
# 39  https://www.redbus.in/bus-tickets/lucknow-to-k...
# 40  https://www.redbus.in/bus-tickets/delhi-to-mor...
# 41  https://www.redbus.in/bus-tickets/haldwani-to-...
# 42  https://www.redbus.in/bus-tickets/aligarh-to-agra
# 43  https://www.redbus.in/bus-tickets/varanasi-to-...
# 44  https://www.redbus.in/bus-tickets/lakhimpur-to...
# 45  https://www.redbus.in/bus-tickets/lucknow-to-m...
# 46  https://www.redbus.in/bus-tickets/allahabad-to...
# 47  https://www.redbus.in/bus-tickets/delhi-to-har...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_up = webdriver.Chrome(service=service)

Bus_names_up = []
Bus_types_up = []
Start_Time_up = []
End_Time_up = []
Ratings_up = []
Total_Duration_up = []
Prices_up = []
Seats_Available_up = []
Route_names = []
Route_links = []

for i, r in df_UP.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_up.get(link)
    time.sleep(2)

    elements = driver_up.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_up.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_up.page_source
        ActionChains(driver_up).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_up.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_up.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_up.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_up.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_up.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_up.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_up.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_up.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_up.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_up.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_up.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_up.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_up.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_up.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_up.append(ratings.text)
    for price_elem in price:
        Prices_up.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_up.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_9 = {
    'Bus_name': Bus_names_up,
    'Bus_type': Bus_types_up,
    'Start_time': Start_Time_up,
    'End_time': End_Time_up,
    'Total_Duration': Total_Duration_up,
    'Price': Prices_up,
    'Seats_Available': Seats_Available_up,
    'Ratings': Ratings_up,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_UP = pd.DataFrame(data_9)
# Convert DataFrame to CSV
path = r"D:\guvi\redbus project\busdetails\df_buses_UP.csv"
df_buses_UP.to_csv(path, index=False)

# %%
df_buses_UP
# Out:
#               Bus_name                                 Bus_type Start_time  \
# 0     UPSRTC - PLB0073                   Shatabdi AC Seater 2+2      12:30
# 1     UPSRTC - RKD0086               Ordinary Non AC Seater 2+3      12:30
# 2     UPSRTC - BLY0151                    Janrath AC Seater 2+2      12:59
# 3     UPSRTC - RKD0083               Ordinary Non AC Seater 2+3      13:11
# 4     UPSRTC - BLY0101                   Shatabdi AC Seater 2+2      13:31
# ..                 ...                                      ...        ...
# 231              NueGo                Electric A/C Seater (2+2)      11:35
# 232       Zingbus Plus  Scania Multi-Axle AC Semi Sleeper (2+2)      15:30
# 233  City Land Travels                        A/C Sleeper (2+1)      20:00
# 234      AdE Bus India                                               23:30
# 235
#
#     End_time Total_Duration    Price     Seats_Available  Ratings  \
# 0      19:01        06h 31m  INR 648  37 Seats available      3.3
# 1      18:30        06h 00m  INR 492  52 Seats available      3.3
# 2      17:45        04h 46m  INR 648  33 Seats available   3.4\n8
# 3      19:01        05h 50m  INR 492  52 Seats available      3.3
# 4      18:30        04h 59m  INR 648  37 Seats available  2.7\n15
# ..       ...            ...      ...                 ...      ...
# 231    17:45        06h 10m      385  12 Seats available  4.3\n81
# 232    20:25        04h 55m      300  40 Seats available  4.7\n16
# 233    01:00        05h 00m      270  32 Seats available  3.9\n55
# 234    04:30        05h 00m  INR 499  32 Seats available      4.2
# 235
#
#                                             Route_link  \
# 0    https://www.redbus.in/bus-tickets/bareilly-to-...
# 1    https://www.redbus.in/bus-tickets/bareilly-to-...
# 2    https://www.redbus.in/bus-tickets/bareilly-to-...
# 3    https://www.redbus.in/bus-tickets/bareilly-to-...
# 4    https://www.redbus.in/bus-tickets/bareilly-to-...
# ..                                                 ...
# 231  https://www.redbus.in/bus-tickets/delhi-to-har...
# 232  https://www.redbus.in/bus-tickets/delhi-to-har...
# 233  https://www.redbus.in/bus-tickets/delhi-to-har...
# 234  https://www.redbus.in/bus-tickets/delhi-to-har...
# 235  https://www.redbus.in/bus-tickets/delhi-to-har...
#
#                             Route_name
# 0    Bareilly (Uttar Pradesh) to Delhi
# 1    Bareilly (Uttar Pradesh) to Delhi
# 2    Bareilly (Uttar Pradesh) to Delhi
# 3    Bareilly (Uttar Pradesh) to Delhi
# 4    Bareilly (Uttar Pradesh) to Delhi
# ..                                 ...
# 231                  Delhi to Haridwar
# 232                  Delhi to Haridwar
# 233                  Delhi to Haridwar
# 234                  Delhi to Haridwar
# 235                  Delhi to Haridwar
#
# [236 rows x 10 columns]

# %%
df_WB=pd.read_csv(r'D:\guvi\redbus project\busroutesandlinks\west_bengal_routes.csv')


# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

chromedriver_path = 'C:\\Users\\vicky\\OneDrive\\Desktop\\chromedriver-win64\\chromedriver.exe'

service = Service(chromedriver_path)
driver_wb = webdriver.Chrome(service=service)

Bus_names_wb = []
Bus_types_wb = []
Start_Time_wb = []
End_Time_wb = []
Ratings_wb = []
Total_Duration_wb = []
Prices_wb = []
Seats_Available_wb = []
Route_names = []
Route_links = []

for i, r in df_WB.iterrows():
    link = r["Route_link"]
    routes = r["Route_name"]

    driver_wb.get(link)
    time.sleep(2)

    elements = driver_wb.find_elements(By.XPATH, f"//a[contains(@href, '{link}')]")
    for element in elements:
        element.click()
        time.sleep(2)

    try:
        clicks = driver_wb.find_element(By.XPATH, "//div[@class='button']")
        clicks.click()
    except:
        continue
    time.sleep(2)

    scrolling = True
    while scrolling:
        old_page_source = driver_wb.page_source
        ActionChains(driver_wb).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(5)
        new_page_source = driver_wb.page_source
        if new_page_source == old_page_source:
            scrolling = False

    bus_name = driver_wb.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type = driver_wb.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    start_time = driver_wb.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    end_time = driver_wb.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    total_duration = driver_wb.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")

    try:
        rating = driver_wb.find_elements(By.XPATH, "//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")
    except:
        continue

    price = driver_wb.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats = driver_wb.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

    for bus in bus_name:
        Bus_names_wb.append(bus.text)
        Route_links.append(link)
        Route_names.append(routes)
    for bus_type_elem in bus_type:
        Bus_types_wb.append(bus_type_elem.text)
    for start_time_elem in start_time:
        Start_Time_wb.append(start_time_elem.text)
    for end_time_elem in end_time:
        End_Time_wb.append(end_time_elem.text)
    for total_duration_elem in total_duration:
        Total_Duration_wb.append(total_duration_elem.text)
    for ratings in rating:
        Ratings_wb.append(ratings.text)
    for price_elem in price:
        Prices_wb.append(price_elem.text)
    for seats_elem in seats:
        Seats_Available_wb.append(seats_elem.text)

print("Successfully Completed")
# Out:
# Successfully Completed

# %%
import pandas as pd

data_10 = {
    'Bus_name': Bus_names_wb,
    'Bus_type': Bus_types_wb,
    'Start_time': Start_Time_wb,
    'End_time': End_Time_wb,
    'Total_Duration': Total_Duration_wb,
    'Price': Prices_wb,
    'Seats_Available': Seats_Available_wb,
    'Ratings': Ratings_wb,
    'Route_link': Route_links,
    'Route_name': Route_names
}

df_buses_WB = pd.DataFrame(data_10)
# Convert DataFrame to CSV
path = r"D:\guvi\redbus project\busdetails\df_buses_WB.csv"
df_buses_WB.to_csv(path, index=False)

# %%
df_buses_WB
# Out:
#                                          Bus_name                    Bus_type  \
# 0     WBTC (CTC) HABRA-DIGHA via Bally - 26|12:50         Non AC Seater (2+3)
# 1     WBTC (CTC) HABRA-DIGHA via Bally - 26|14:50         Non AC Seater (2+3)
# 2   WBTC (CTC) BARASAT-DIGHA via Bally - 38|15:35         Non AC Seater (2+3)
# 3                                    The Joy Ride  A/C Seater / Sleeper (2+2)
# 4                                 Satya Paribahan            A/C Seater (2+3)
# ..                                            ...                         ...
# 94
# 95
# 96
# 97
# 98
#
#    Start_time End_time Total_Duration    Price     Seats_Available  Ratings  \
# 0       12:50    17:35        04h 45m  INR 161  32 Seats available  3.8\n43
# 1       14:50    19:35        04h 45m  INR 161  41 Seats available  3.7\n69
# 2       15:35    20:50        05h 15m  INR 161  43 Seats available      3.5
# 3       21:15    03:35        06h 20m  INR 650  49 Seats available      3.8
# 4       23:00    05:10        06h 10m  INR 320  30 Seats available  3.6\n39
# ..        ...      ...            ...      ...                 ...      ...
# 94
# 95
# 96
# 97
# 98
#
#                                            Route_link  \
# 0   https://www.redbus.in/bus-tickets/digha-to-bar...
# 1   https://www.redbus.in/bus-tickets/digha-to-bar...
# 2   https://www.redbus.in/bus-tickets/digha-to-bar...
# 3   https://www.redbus.in/bus-tickets/digha-to-bar...
# 4   https://www.redbus.in/bus-tickets/digha-to-bar...
# ..                                                ...
# 94  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 95  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 96  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 97  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 98  https://www.redbus.in/bus-tickets/kolkata-to-h...
#
#                         Route_name
# 0   Digha to Barasat (West Bengal)
# 1   Digha to Barasat (West Bengal)
# 2   Digha to Barasat (West Bengal)
# 3   Digha to Barasat (West Bengal)
# 4   Digha to Barasat (West Bengal)
# ..                             ...
# 94               Kolkata to Haldia
# 95               Kolkata to Haldia
# 96               Kolkata to Haldia
# 97               Kolkata to Haldia
# 98               Kolkata to Haldia
#
# [99 rows x 10 columns]
